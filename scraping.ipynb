# %% [markdown]
# # Import Library

# %%
# !pip install google-play-scraper

from google_play_scraper import reviews_all, Sort
import csv
import pandas as pd
# Out:
# Requirement already satisfied: google-play-scraper in /usr/local/lib/python3.11/dist-packages (1.2.7)

# %% [markdown]
# # Scraping Dataset

# %%
scrapreview = reviews_all(
    'com.duolingo',               # ID aplikasi
    lang='id',                    # Bahasa ulasan (default: 'en')
    country='id',                 # Negara (default: 'us')
    sort=Sort.MOST_RELEVANT,      # Urutan ulasan (default: Sort.MOST_RELEVANT)
    count=10000                   # Jumlah maksimum ulasan yang ingin diambil
)

# %%
with open('ulasan_aplikasi.csv', mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerow(['Review'])  # Menulis header kolom
    for review in scrapreview:
        writer.writerow([review['content']])  # Menulis konten ulasan ke dalam file CSV

# %% [markdown]
# # Loading Dataset

# %%
app_reviews_df = pd.DataFrame(scrapreview)
app_reviews_df.shape
app_reviews_df.head()
app_reviews_df.to_csv('ulasan_aplikasi.csv', index=False)

app_reviews_df = pd.DataFrame(scrapreview)

# %%
# Menghitung jumlah baris dan kolom dalam DataFrame
jumlah_ulasan, jumlah_kolom = app_reviews_df.shape
print(f'Jumlah ulasan: {jumlah_ulasan}')
print(f'Jumlah kolom: {jumlah_kolom}')
# Out:
# Jumlah ulasan: 13500
# Jumlah kolom: 11

# %%
app_reviews_df.head()
# Out:
#                                reviewId         userName  \
# 0  5014d583-276e-4f93-a01c-03913f55b905  Pengguna Google
# 1  d140767b-1c9a-41e6-8612-9b697fbf3e01  Pengguna Google
# 2  fa3bd275-a55e-4456-b3bc-e92ccf3f2553  Pengguna Google
# 3  3be5a1a7-f510-4cc7-9992-c64649e0e66f  Pengguna Google
# 4  e9f41834-10fa-4d95-8d7c-d6dc44957d56  Pengguna Google
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/EGemoI2N...
# 1  https://play-lh.googleusercontent.com/EGemoI2N...
# 2  https://play-lh.googleusercontent.com/EGemoI2N...
# 3  https://play-lh.googleusercontent.com/EGemoI2N...
# 4  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                              content  score  thumbsUpCount  \
# 0  Sejauh 2 tahun saya pakai emang apk nya bagus ...      5             67
# 1  sebelumnya cukup sulit untuk mengumpulkan 5 He...      5             17
# 2  Jujur suka banget belajar bahasa kalau pakai D...      5            470
# 3  saya kasih bintang 1. pas saya mau belajar bah...      1              1
# 4  kenapa ya,,, pas mau login lagi nggak bisa mas...      1              0
#
#   reviewCreatedVersion                  at replyContent repliedAt appVersion
# 0               6.20.3 2025-03-14 03:48:21         None      None     6.20.3
# 1               6.22.3 2025-03-23 13:31:14         None      None     6.22.3
# 2               6.22.3 2025-03-22 11:03:40         None      None     6.22.3
# 3               6.22.3 2025-03-24 12:40:37         None      None     6.22.3
# 4               6.19.2 2025-02-28 15:22:22         None      None     6.19.2
